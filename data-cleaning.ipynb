# %% [markdown]
# ### Importation des librairies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/location_analytics/projet/NYPD_Complaint_Data_Historic_2019.csv")

# %%
data.describe()
# Out:
#          CMPLNT_NUM    ADDR_PCT_CD          KY_CD          PD_CD  \
# count  4.509760e+05  450976.000000  450976.000000  450684.000000
# mean   5.503813e+08      62.180433     307.608726     400.201833
# std    2.599473e+08      35.191337     156.225466     216.812809
# min    1.000004e+08     -99.000000     101.000000     100.000000
# 25%    3.250634e+08      34.000000     121.000000     254.000000
# 50%    5.508529e+08      62.000000     341.000000     343.000000
# 75%    7.758643e+08      90.000000     351.000000     637.000000
# max    9.999959e+08     123.000000     881.000000     969.000000
#
#        JURISDICTION_CODE   HOUSING_PSA    X_COORD_CD     Y_COORD_CD  \
# count      450684.000000  32512.000000  4.509760e+05  450976.000000
# mean            0.917321   7183.512549  1.005165e+06  207900.129750
# std             8.133532  14608.026841  2.112529e+04   30105.366883
# min             0.000000    218.000000  9.137840e+05  121152.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450976 entries, 0 to 450975
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CMPLNT_NUM         450976 non-null  int64
#  1   CMPLNT_FR_DT       450976 non-null  object
#  2   CMPLNT_FR_TM       450976 non-null  object
#  3   CMPLNT_TO_DT       394679 non-null  object
#  4   CMPLNT_TO_TM       394912 non-null  object
#  5   ADDR_PCT_CD        450976 non-null  float64
#  6   RPT_DT             450976 non-null  object
#  7   KY_CD              450976 non-null  int64
#  8   OFNS_DESC          450968 non-null  object
#  9   PD_CD              450684 non-null  float64
#  10  PD_DESC            450684 non-null  object
#  11  CRM_ATPT_CPTD_CD   450976 non-null  object
#  12  LAW_CAT_CD         450976 non-null  object
#  13  BORO_NM            450677 non-null  object
#  14  LOC_OF_OCCUR_DESC  369242 non-null  object
# ...

# %%
data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   552996231   2019-01-01     16:25:00          NaN          NaN
# 1   807279950   2019-01-02     19:50:00          NaN          NaN
# 2   508802958   2019-01-02     22:00:00   01/02/2019     22:10:00
# 3   259858195   2019-01-02     19:45:00   01/03/2019     09:30:00
# 4   531549247   2019-01-03     15:01:00          NaN          NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD          OFNS_DESC  PD_CD  ...  \
# 0         90.0  01/01/2019    118  DANGEROUS WEAPONS  793.0  ...
# 1         43.0  01/02/2019    106     FELONY ASSAULT  105.0  ...
# 2         13.0  01/02/2019    106     FELONY ASSAULT  109.0  ...
# 3         49.0  01/03/2019    107           BURGLARY  213.0  ...
# 4         14.0  01/03/2019    105            ROBBERY  396.0  ...
#
#   TRANSIT_DISTRICT   Latitude  Longitude  \
# 0              NaN  40.701528 -73.943227
# 1              NaN  40.822738 -73.861370
# 2              NaN  40.741944 -73.997223
# ...

# %%
#The dataset size
print("Observations: ", data.shape[0])

#The number of variables
print("Variables: ", data.shape[1])
# Out:
# Observations:  450976
# Variables:  36

# %%
data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   552996231   2019-01-01     16:25:00          NaN          NaN
# 1   807279950   2019-01-02     19:50:00          NaN          NaN
# 2   508802958   2019-01-02     22:00:00   01/02/2019     22:10:00
# 3   259858195   2019-01-02     19:45:00   01/03/2019     09:30:00
# 4   531549247   2019-01-03     15:01:00          NaN          NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD          OFNS_DESC  PD_CD  ...  \
# 0         90.0  01/01/2019    118  DANGEROUS WEAPONS  793.0  ...
# 1         43.0  01/02/2019    106     FELONY ASSAULT  105.0  ...
# 2         13.0  01/02/2019    106     FELONY ASSAULT  109.0  ...
# 3         49.0  01/03/2019    107           BURGLARY  213.0  ...
# 4         14.0  01/03/2019    105            ROBBERY  396.0  ...
#
#   TRANSIT_DISTRICT   Latitude  Longitude  \
# 0              NaN  40.701528 -73.943227
# 1              NaN  40.822738 -73.861370
# 2              NaN  40.741944 -73.997223
# ...

# %%
# Convert complaintfromdatetime and complaint to datetime to datetypes
data['CMPLNT_FR_DT'] = pd.to_datetime(data['CMPLNT_FR_DT'], errors='coerce')
data['CMPLNT_TO_DT'] = pd.to_datetime(data['CMPLNT_TO_DT'], errors='coerce')

# %%
data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   552996231   2019-01-01     16:25:00          NaT          NaN
# 1   807279950   2019-01-02     19:50:00          NaT          NaN
# 2   508802958   2019-01-02     22:00:00   2019-01-02     22:10:00
# 3   259858195   2019-01-02     19:45:00   2019-01-03     09:30:00
# 4   531549247   2019-01-03     15:01:00          NaT          NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD          OFNS_DESC  PD_CD  ...  \
# 0         90.0  01/01/2019    118  DANGEROUS WEAPONS  793.0  ...
# 1         43.0  01/02/2019    106     FELONY ASSAULT  105.0  ...
# 2         13.0  01/02/2019    106     FELONY ASSAULT  109.0  ...
# 3         49.0  01/03/2019    107           BURGLARY  213.0  ...
# 4         14.0  01/03/2019    105            ROBBERY  396.0  ...
#
#   TRANSIT_DISTRICT   Latitude  Longitude  \
# 0              NaN  40.701528 -73.943227
# 1              NaN  40.822738 -73.861370
# 2              NaN  40.741944 -73.997223
# ...

# %%
#Extract the time range(days) of the occurance of the accident 
#td='Time_Duration'
#data[td]=round((data['CMPLNT_TO_DT']-data['CMPLNT_FR_DT'])/np.timedelta64(1,'D'))

# %%
#cmplt_fr_dt c est la date exacte de l'occurence of the reported event
#cmplt_to_dt c est la date of the ending of the reported event
#cmplt_fr_tm c est le temps exacte de l'occurence of the reported event
#cmplt_to_tm c est le temps exacte de l'occurence of the reported event

# %%
data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   552996231   2019-01-01     16:25:00          NaT          NaN
# 1   807279950   2019-01-02     19:50:00          NaT          NaN
# 2   508802958   2019-01-02     22:00:00   2019-01-02     22:10:00
# 3   259858195   2019-01-02     19:45:00   2019-01-03     09:30:00
# 4   531549247   2019-01-03     15:01:00          NaT          NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD          OFNS_DESC  PD_CD  ...  \
# 0         90.0  01/01/2019    118  DANGEROUS WEAPONS  793.0  ...
# 1         43.0  01/02/2019    106     FELONY ASSAULT  105.0  ...
# 2         13.0  01/02/2019    106     FELONY ASSAULT  109.0  ...
# 3         49.0  01/03/2019    107           BURGLARY  213.0  ...
# 4         14.0  01/03/2019    105            ROBBERY  396.0  ...
#
#   TRANSIT_DISTRICT   Latitude  Longitude  \
# 0              NaN  40.701528 -73.943227
# 1              NaN  40.822738 -73.861370
# 2              NaN  40.741944 -73.997223
# ...

# %%
data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   552996231   2019-01-01     16:25:00          NaT          NaN
# 1   807279950   2019-01-02     19:50:00          NaT          NaN
# 2   508802958   2019-01-02     22:00:00   2019-01-02     22:10:00
# 3   259858195   2019-01-02     19:45:00   2019-01-03     09:30:00
# 4   531549247   2019-01-03     15:01:00          NaT          NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD          OFNS_DESC  PD_CD  ...  \
# 0         90.0  01/01/2019    118  DANGEROUS WEAPONS  793.0  ...
# 1         43.0  01/02/2019    106     FELONY ASSAULT  105.0  ...
# 2         13.0  01/02/2019    106     FELONY ASSAULT  109.0  ...
# 3         49.0  01/03/2019    107           BURGLARY  213.0  ...
# 4         14.0  01/03/2019    105            ROBBERY  396.0  ...
#
#   TRANSIT_DISTRICT   Latitude  Longitude  \
# 0              NaN  40.701528 -73.943227
# 1              NaN  40.822738 -73.861370
# 2              NaN  40.741944 -73.997223
# ...

# %% [markdown]
# ### Dealing with outliers

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450976 entries, 0 to 450975
# Data columns (total 36 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CMPLNT_NUM         450976 non-null  int64
#  1   CMPLNT_FR_DT       450976 non-null  datetime64[ns]
#  2   CMPLNT_FR_TM       450976 non-null  object
#  3   CMPLNT_TO_DT       394679 non-null  datetime64[ns]
#  4   CMPLNT_TO_TM       394912 non-null  object
#  5   ADDR_PCT_CD        450976 non-null  float64
#  6   RPT_DT             450976 non-null  object
#  7   KY_CD              450976 non-null  int64
#  8   OFNS_DESC          450968 non-null  object
#  9   PD_CD              450684 non-null  float64
#  10  PD_DESC            450684 non-null  object
#  11  CRM_ATPT_CPTD_CD   450976 non-null  object
#  12  LAW_CAT_CD         450976 non-null  object
#  13  BORO_NM            450677 non-null  object
#  14  LOC_OF_OCCUR_DESC  369242 non-null  object
# ...

# %%
#PARK_NM has only 232 non-null , TRANSIT_DISTRICT has only 409 non-null , STATION_NAME has only 409 non-null , HADEVELOPT has only 2225 non-null
#So i aim to delete these columns

# %%
data.drop(axis=0, columns=["SUSP_AGE_GROUP", "SUSP_RACE", "HADEVELOPT", "HOUSING_PSA" , "SUSP_SEX" , 'JURISDICTION_CODE', 'CMPLNT_TO_DT' , 'CMPLNT_TO_TM'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450976 entries, 0 to 450975
# Data columns (total 28 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CMPLNT_NUM         450976 non-null  int64
#  1   CMPLNT_FR_DT       450976 non-null  datetime64[ns]
#  2   CMPLNT_FR_TM       450976 non-null  object
#  3   ADDR_PCT_CD        450976 non-null  float64
#  4   RPT_DT             450976 non-null  object
#  5   KY_CD              450976 non-null  int64
#  6   OFNS_DESC          450968 non-null  object
#  7   PD_CD              450684 non-null  float64
#  8   PD_DESC            450684 non-null  object
#  9   CRM_ATPT_CPTD_CD   450976 non-null  object
#  10  LAW_CAT_CD         450976 non-null  object
#  11  BORO_NM            450677 non-null  object
#  12  LOC_OF_OCCUR_DESC  369242 non-null  object
#  13  PREM_TYP_DESC      449191 non-null  object
#  14  JURIS_DESC         450976 non-null  object
# ...

# %%
#dropping rows with NaN values
data.dropna(subset=['PARKS_NM','Y_COORD_CD','X_COORD_CD','Latitude','Longitude','CRM_ATPT_CPTD_CD','CMPLNT_FR_TM','Lat_Lon','CMPLNT_FR_DT','BORO_NM'], inplace=True)

# %%
data.head()
# Out:
#       CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM  ADDR_PCT_CD      RPT_DT  KY_CD  \
# 275    232973689   2019-04-23     16:18:00         44.0  04/23/2019    105
# 487    398182220   2019-06-29     01:30:00        103.0  07/24/2019    341
# 884    791045583   2019-01-10     18:30:00         84.0  01/10/2019    106
# 1050   552549706   2019-01-04     04:22:00         22.0  01/04/2019    110
# 1090   894206441   2019-01-03     11:09:00         40.0  01/03/2019    235
#
#                            OFNS_DESC  PD_CD                         PD_DESC  \
# 275                          ROBBERY  366.0                 ROBBERY,BICYCLE
# 487                    PETIT LARCENY  339.0  LARCENY,PETIT FROM OPEN AREAS,
# 884                   FELONY ASSAULT  109.0        ASSAULT 2,1,UNCLASSIFIED
# 1050  GRAND LARCENY OF MOTOR VEHICLE  441.0           LARCENY,GRAND OF AUTO
# 1090                 DANGEROUS DRUGS  511.0  CONTROLLED SUBSTANCE, POSSESSI
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3995 entries, 275 to 450569
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CMPLNT_NUM         3995 non-null   int64
#  1   CMPLNT_FR_DT       3995 non-null   datetime64[ns]
#  2   CMPLNT_FR_TM       3995 non-null   object
#  3   ADDR_PCT_CD        3995 non-null   float64
#  4   RPT_DT             3995 non-null   object
#  5   KY_CD              3995 non-null   int64
#  6   OFNS_DESC          3995 non-null   object
#  7   PD_CD              3995 non-null   float64
#  8   PD_DESC            3995 non-null   object
#  9   CRM_ATPT_CPTD_CD   3995 non-null   object
#  10  LAW_CAT_CD         3995 non-null   object
#  11  BORO_NM            3995 non-null   object
#  12  LOC_OF_OCCUR_DESC  1547 non-null   object
#  13  PREM_TYP_DESC      3991 non-null   object
#  14  JURIS_DESC         3995 non-null   object
# ...

# %%
# Export the data
data.to_csv('C:/location_analytics/projet/NYPD_Complaint_Data_Historic_2019_clean.csv',index=False)
